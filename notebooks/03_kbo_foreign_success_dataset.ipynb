# %% [markdown]
# # 03_kbo_foreign_success_dataset: KBO Foreign Success Dataset
#
# 목표: KBO 외국인 선수의 입단 전 feature와 입단 후 success label을 분리한 backtest dataset을 구축한다.
#
# 핵심 가설: 성공/실패의 공통 패턴을 모르면 현재 후보 랭킹은 이름값과 표면 성적에 끌려간다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '03_kbo_foreign_success_dataset'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `data/raw/kbo/`
# - `data/raw/mlb_milb/`
# - `data/raw/npb/`
#
# ## Outputs
#
# - `data/processed/foreign_transfer_history.parquet`
# - `outputs/tables/foreign_success_labels.csv`

# %%
phase_contract = {
    'phase': '03_kbo_foreign_success_dataset',
    'objective': 'KBO 외국인 선수의 입단 전 feature와 입단 후 success label을 분리한 backtest dataset을 구축한다.',
    'inputs': ['data/raw/kbo/', 'data/raw/mlb_milb/', 'data/raw/npb/'],
    'outputs': ['data/processed/foreign_transfer_history.parquet', 'outputs/tables/foreign_success_labels.csv'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - 2018년 이후 외국인 명단 수집
# - role별 success label 적용
# - feature/label leakage 검사
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
