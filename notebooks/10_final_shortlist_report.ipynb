# %% [markdown]
# # 10_final_shortlist_report: Final Shortlist Report
#
# 목표: 검증된 랭킹과 최신 availability를 결합해 role별 Top 5-10, 최종 1-3순위, scouting report를 생성한다.
#
# 핵심 가설: 최종 후보는 점수뿐 아니라 결함, SSG fit, KBO 전환, 영입 가능성을 한 문장으로 설명할 수 있어야 한다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '10_final_shortlist_report'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `data/processed/*_features.parquet`
# - `outputs/tables/ranking_validation_metrics.csv`
# - `reports/templates/`
#
# ## Outputs
#
# - `outputs/candidates/final_shortlist.csv`
# - `outputs/reports/final_report.md`
# - `outputs/reports/presentation_outline.md`

# %%
phase_contract = {
    'phase': '10_final_shortlist_report',
    'objective': '검증된 랭킹과 최신 availability를 결합해 role별 Top 5-10, 최종 1-3순위, scouting report를 생성한다.',
    'inputs': ['data/processed/*_features.parquet', 'outputs/tables/ranking_validation_metrics.csv', 'reports/templates/'],
    'outputs': ['outputs/candidates/final_shortlist.csv', 'outputs/reports/final_report.md', 'outputs/reports/presentation_outline.md'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - 최신 로스터/계약/부상 재확인
# - role별 shortlist 생성
# - scouting report 작성
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
