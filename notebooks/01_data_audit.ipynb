# %% [markdown]
# # 01_data_audit: Data Audit
#
# 목표: KBO, MLB/MiLB, NPB, 기사/인터뷰, 날씨/구장 데이터의 실제 접근 가능성과 컬럼 품질을 검증한다.
#
# 핵심 가설: 수집 가능성과 컬럼 정의를 먼저 고정해야 feature hypothesis를 현실적인 분석 변수로 바꿀 수 있다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '01_data_audit'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `docs/source_log.md`
# - `data/schemas/*.csv`
#
# ## Outputs
#
# - `outputs/tables/source_audit_result.csv`
# - `docs/source_log.md 업데이트`

# %%
phase_contract = {
    'phase': '01_data_audit',
    'objective': 'KBO, MLB/MiLB, NPB, 기사/인터뷰, 날씨/구장 데이터의 실제 접근 가능성과 컬럼 품질을 검증한다.',
    'inputs': ['docs/source_log.md', 'data/schemas/*.csv'],
    'outputs': ['outputs/tables/source_audit_result.csv', 'docs/source_log.md 업데이트'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - 각 출처별 다운로드/표 접근 여부 확인
# - 약관/라이선스 주의사항 기록
# - 실제 raw 파일 저장 규칙 확정
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
