# %% [markdown]
# # 00_problem_definition: Problem Definition
#
# 목표: SSG 랜더스 대체 외국인/아시아쿼터 영입 문제를 metric, leakage rule, role별 의사결정 구조로 고정한다.
#
# 핵심 가설: 선수 추천의 품질은 모델 복잡도보다 문제 정의와 성공 기준의 명확성에 먼저 좌우된다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '00_problem_definition'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `docs/initial_project_plan.md`
# - `docs/methodology.md`
#
# ## Outputs
#
# - `outputs/reports/problem_definition_summary.md`

# %%
phase_contract = {
    'phase': '00_problem_definition',
    'objective': 'SSG 랜더스 대체 외국인/아시아쿼터 영입 문제를 metric, leakage rule, role별 의사결정 구조로 고정한다.',
    'inputs': ['docs/initial_project_plan.md', 'docs/methodology.md'],
    'outputs': ['outputs/reports/problem_definition_summary.md'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - role별 score weight 초안 검토
# - success label과 final score 정의 확정
# - leakage 금지 컬럼 목록 재확인
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
