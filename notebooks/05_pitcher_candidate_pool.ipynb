# %% [markdown]
# # 05_pitcher_candidate_pool: Pitcher Candidate Pool
#
# 목표: AAA/MLB borderline 선발 및 swingman 후보를 만들고 구위, 제구, 이닝, ABS 적응 변수를 계산한다.
#
# 핵심 가설: KBO 외국인 선발은 화려한 구속보다 볼넷 억제, 주무기, 120이닝 가능성이 실패를 가른다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '05_pitcher_candidate_pool'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `data/raw/mlb_milb/`
# - `data/processed/ssg_need_scores.csv`
#
# ## Outputs
#
# - `outputs/candidates/starter_longlist.csv`
# - `outputs/tables/starter_feature_summary.csv`

# %%
phase_contract = {
    'phase': '05_pitcher_candidate_pool',
    'objective': 'AAA/MLB borderline 선발 및 swingman 후보를 만들고 구위, 제구, 이닝, ABS 적응 변수를 계산한다.',
    'inputs': ['data/raw/mlb_milb/', 'data/processed/ssg_need_scores.csv'],
    'outputs': ['outputs/candidates/starter_longlist.csv', 'outputs/tables/starter_feature_summary.csv'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - starter/swingman 후보 필터
# - pitch arsenal feature 생성
# - walk risk와 inning eating score 계산
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
