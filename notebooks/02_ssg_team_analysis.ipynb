# %% [markdown]
# # 02_ssg_team_analysis: SSG Team Analysis
#
# 목표: 2023-2026 SSG 타격, 선발, 불펜, 수비/주루, 홈구장 맥락을 리그 평균/순위와 비교한다.
#
# 핵심 가설: 외국인/아시아쿼터 추천은 SSG의 실제 결핍 위치를 먼저 계량화해야 설득력을 가진다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '02_ssg_team_analysis'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `data/raw/kbo/`
# - `data/raw/park/`
# - `data/raw/weather/`
#
# ## Outputs
#
# - `outputs/reports/ssg_team_diagnosis.md`
# - `outputs/tables/ssg_need_scores.csv`

# %%
phase_contract = {
    'phase': '02_ssg_team_analysis',
    'objective': '2023-2026 SSG 타격, 선발, 불펜, 수비/주루, 홈구장 맥락을 리그 평균/순위와 비교한다.',
    'inputs': ['data/raw/kbo/', 'data/raw/park/', 'data/raw/weather/'],
    'outputs': ['outputs/reports/ssg_team_diagnosis.md', 'outputs/tables/ssg_need_scores.csv'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - 팀 타격 지표 수집
# - 선발/불펜 role split 생성
# - 보강 우선순위 초안 작성
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
