# %% [markdown]
# # 07_feature_engineering: Feature Engineering
#
# 목표: SSG/KBO 특화 feature를 0-100 score로 정규화하고 role별 feature matrix를 만든다.
#
# 핵심 가설: 발표 경쟁력은 일반 지표보다 SSG Need Fit, ABS, Park Fit, Acquirable Flaw 같은 맥락형 변수에서 나온다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '07_feature_engineering'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `outputs/candidates/*_longlist.csv`
# - `docs/methodology.md`
#
# ## Outputs
#
# - `data/processed/hitter_features.parquet`
# - `data/processed/starter_features.parquet`
# - `data/processed/asian_reliever_features.parquet`

# %%
phase_contract = {
    'phase': '07_feature_engineering',
    'objective': 'SSG/KBO 특화 feature를 0-100 score로 정규화하고 role별 feature matrix를 만든다.',
    'inputs': ['outputs/candidates/*_longlist.csv', 'docs/methodology.md'],
    'outputs': ['data/processed/hitter_features.parquet', 'data/processed/starter_features.parquet', 'data/processed/asian_reliever_features.parquet'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - score normalization 함수 작성
# - 결측 proxy flag 추가
# - feature importance 설명문 생성
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
