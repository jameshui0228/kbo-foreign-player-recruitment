# %% [markdown]
# # 06_asian_quota_candidate_pool: Asian Quota Candidate Pool
#
# 목표: NPB 1군 하위/팜 상위/독립리그/CPBL/ABL 불펜 후보를 아시아쿼터 관점에서 정리한다.
#
# 핵심 가설: 아시아쿼터의 최대 가치는 SSG 불펜의 특정 결함을 낮은 비용으로 메우는 고레버리지 투수일 수 있다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '06_asian_quota_candidate_pool'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `data/raw/npb/`
# - `data/raw/articles/`
# - `data/processed/ssg_need_scores.csv`
#
# ## Outputs
#
# - `outputs/candidates/asian_reliever_longlist.csv`
# - `outputs/tables/asian_reliever_feature_summary.csv`

# %%
phase_contract = {
    'phase': '06_asian_quota_candidate_pool',
    'objective': 'NPB 1군 하위/팜 상위/독립리그/CPBL/ABL 불펜 후보를 아시아쿼터 관점에서 정리한다.',
    'inputs': ['data/raw/npb/', 'data/raw/articles/', 'data/processed/ssg_need_scores.csv'],
    'outputs': ['outputs/candidates/asian_reliever_longlist.csv', 'outputs/tables/asian_reliever_feature_summary.csv'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - NPB/Farm reliever pool 정의
# - low walk/short burst stuff proxy 생성
# - role fit score 계산
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
