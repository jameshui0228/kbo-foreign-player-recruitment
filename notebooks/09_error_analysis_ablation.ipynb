# %% [markdown]
# # 09_error_analysis_ablation: Error Analysis Ablation
#
# 목표: 성공 저평가/실패 고평가 사례를 분석하고 feature ablation으로 과적합 변수를 찾는다.
#
# 핵심 가설: 모델 교체보다 오류 segment를 해석하는 것이 shortlist 신뢰도를 더 크게 높인다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '09_error_analysis_ablation'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `outputs/tables/oof_predictions.csv`
# - `data/processed/foreign_transfer_history.parquet`
#
# ## Outputs
#
# - `outputs/tables/error_cases.csv`
# - `outputs/tables/ablation_results.csv`
# - `outputs/reports/error_analysis.md`

# %%
phase_contract = {
    'phase': '09_error_analysis_ablation',
    'objective': '성공 저평가/실패 고평가 사례를 분석하고 feature ablation으로 과적합 변수를 찾는다.',
    'inputs': ['outputs/tables/oof_predictions.csv', 'data/processed/foreign_transfer_history.parquet'],
    'outputs': ['outputs/tables/error_cases.csv', 'outputs/tables/ablation_results.csv', 'outputs/reports/error_analysis.md'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - false positive/false negative 그룹화
# - 리그/나이/포지션별 오류 확인
# - feature ablation 실행
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
