# %% [markdown]
# # 04_hitter_candidate_pool: Hitter Candidate Pool
#
# 목표: MLB 40-man 밖/AAA-AA 중심의 외국인 타자 후보 longlist를 만들고 장타/전환/결함 변수를 계산한다.
#
# 핵심 가설: SSG에 필요한 타자는 단순 OPS 상위가 아니라 KBO 변화구와 문학 구장에 맞는 장타 profile을 가진 선수다.

# %%
from __future__ import annotations

from pathlib import Path
import json
import random

SEED = 7
random.seed(SEED)
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PHASE = '04_hitter_candidate_pool'
PROJECT_ROOT, PHASE, SEED

# %% [markdown]
# ## Inputs
#
# - `data/raw/mlb_milb/`
# - `data/processed/ssg_need_scores.csv`
#
# ## Outputs
#
# - `outputs/candidates/hitter_longlist.csv`
# - `outputs/tables/hitter_feature_summary.csv`

# %%
phase_contract = {
    'phase': '04_hitter_candidate_pool',
    'objective': 'MLB 40-man 밖/AAA-AA 중심의 외국인 타자 후보 longlist를 만들고 장타/전환/결함 변수를 계산한다.',
    'inputs': ['data/raw/mlb_milb/', 'data/processed/ssg_need_scores.csv'],
    'outputs': ['outputs/candidates/hitter_longlist.csv', 'outputs/tables/hitter_feature_summary.csv'],
}
phase_contract

# %% [markdown]
# ## Work Plan
#
# - AAA/AA hitter pool 정의
# - Statcast 타구질 merge
# - availability filter 적용
#
# ## Notes
#
# - 데이터 출처와 접근일은 `docs/source_log.md`에 반드시 남긴다.
# - KBO 입단 후 성적은 label로만 사용하고 feature로 사용하지 않는다.
# - 결측 데이터는 추측하지 않고 proxy와 한계를 함께 기록한다.
